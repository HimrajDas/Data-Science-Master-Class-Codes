# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file("test.html")

p = figure(title="test_flower")
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers["petal_length"], flowers["petal_width"])
show(p)
# Out:
#   <div id="e0163b01-3cfc-4d7e-88f5-369751ff0c61" data-root-id="p1193" style="display: contents;"></div>

# %%
x = [2, 3, 4 ,5 , 7]
y = [10, 34, 2, 56, 6]
output_file("line.html")
p = figure(title="line graph")
p.line(x, y)
show(p)
# Out:
#   <div id="a2d12ac6-1c18-4128-ae95-1dacaaf02072" data-root-id="p1429" style="display: contents;"></div>

# %%
x = [2, 3, 4 ,5 , 7]
y = [10, 34, 2, 56, 6]
output_file("scatter.html")
p = figure(title="scatter graph")
p.scatter(x, y, size=10, fill_color="blue", legend_label="this is my data point")
show(p)
# Out:
#   <div id="6b580c9f-b804-4deb-a093-e183b72c5ed0" data-root-id="p1674" style="display: contents;"></div>
